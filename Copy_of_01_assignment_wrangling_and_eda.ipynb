# %% [markdown]
# <a href="https://colab.research.google.com/github/zry3fr/DS-2002-F25/blob/main/Copy_of_01_assignment_wrangling_and_eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! git clone https://github.com/zry3fr/scratchpad
# %run ./scratchpad/get_data.py
# Out:
# Cloning into 'scratchpad'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 33 (delta 10), reused 4 (delta 4), pack-reused 19 (from 1)
# Receiving objects: 100% (33/33), 42.65 KiB | 2.37 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# Downloading course data...
# Download complete
# Extracting data files...
# Data extracted

# %% [markdown]
# # Assignment 1: Wrangling and EDA
# ### Foundations of Machine Learning

# %% [markdown]
# **Q1.** This question provides some practice cleaning variables which have common problems.

# %% [markdown]
# 1.

# %%
import pandas as pd

# %%
airbnb = pd.read_csv(
    '/content/data/airbnb_NYC.csv',
    encoding='latin1'
)
airbnb.head()
# Out:
#     Host Id Host Since                                Name Neighbourhood   \
# 0   5162530        NaN     1 Bedroom in Prime Williamsburg       Brooklyn
# 1  33134899        NaN     Sunny, Private room in Bushwick       Brooklyn
# 2  39608626        NaN                Sunny Room in Harlem      Manhattan
# 3       500  6/26/2008  Gorgeous 1 BR with Private Balcony      Manhattan
# 4       500  6/26/2008            Trendy Times Square Loft      Manhattan
#
#   Property Type  Review Scores Rating (bin)        Room Type  Zipcode  Beds  \
# 0     Apartment                         NaN  Entire home/apt  11249.0   1.0
# 1     Apartment                         NaN     Private room  11206.0   1.0
# 2     Apartment                         NaN     Private room  10032.0   1.0
# 3     Apartment                         NaN  Entire home/apt  10024.0   3.0
# 4     Apartment                        95.0     Private room  10036.0   3.0
#
#    Number of Records  Number Of Reviews Price  Review Scores Rating
# 0                  1                  0   145                   NaN
# 1                  1                  1    37                   NaN
# 2                  1                  1    28                   NaN
# 3                  1                  0   199                   NaN
# 4                  1                 39   549                  96.0

# %%
price_clean = (
    airbnb['Price']
    .astype(str)
    .str.replace(',', '', regex=False)
)

price_numeric = pd.to_numeric(price_clean, errors='coerce')

# %% [markdown]
# I converted everything in the price column into strings to ensure consistent datatypes. Then, I removed the commas which are just thousand separators and are not meaningful numerically. Lastly, I converted the values numeric using 'to_numeric' while also making invalid values appear as 'NaN'.

# %%
airbnb['Price']
# Out:
# 0        145
# 1         37
# 2         28
# 3        199
# 4        549
#         ...
# 30473    300
# 30474    125
# 30475     80
# 30476     35
# 30477     80
# Name: Price, Length: 30478, dtype: object

# %% [markdown]
# After cleaning, there are 0 missing values. All entries under the price column are valid numbers.

# %% [markdown]
# 2.

# %%
import numpy as np

# %%
force = pd.read_csv('/content/data/mn_police_use_of_force.csv', encoding='latin1')
force.head()
# Out:
#      response_datetime               problem is_911_call primary_offense  \
# 0  2016/01/01 00:47:36  Assault in Progress          Yes          DASLT1
# 1  2016/01/01 02:19:34                Fight           No          DISCON
# 2  2016/01/01 02:19:34                Fight           No          DISCON
# 3  2016/01/01 02:28:48                Fight           No          PRIORI
# 4  2016/01/01 02:28:48                Fight           No          PRIORI
#
#   subject_injury         force_type   force_type_action   race     sex   age  \
# 0            NaN       Bodily Force  Body Weight to Pin  Black    Male  20.0
# 1            NaN  Chemical Irritant       Personal Mace  Black  Female  27.0
# 2            NaN  Chemical Irritant       Personal Mace  White  Female  23.0
# 3            NaN  Chemical Irritant  Crowd Control Mace  Black    Male  20.0
# 4            NaN  Chemical Irritant  Crowd Control Mace  Black    Male  20.0
#
#          type_resistance  precinct   neighborhood
# 0                 Tensed         1  Downtown East
# 1  Verbal Non-Compliance         1  Downtown West
# 2  Verbal Non-Compliance         1  Downtown West
# 3    Commission of Crime         1  Downtown West
# 4    Commission of Crime         1  Downtown West

# %%
orig_counts = force['subject_injury'].value_counts(dropna=False)
orig_counts
# Out:
# subject_injury
# NaN    9848
# Yes    1631
# No     1446
# Name: count, dtype: int64

# %%
missing_prop = force['subject_injury'].isna().mean()
missing_prop
# Out:
# np.float64(0.7619342359767892)

# %%
force['subject_injury_clean'] = (
    force['subject_injury']
    .astype('string')
    .str.strip()
    .str.lower()
    .map({
        'yes': 'Yes',
        'y': 'Yes',
        'true': 'Yes',
        'injured': 'Yes',
        'no': 'No',
        'n': 'No',
        'false': 'No',
        'not injured': 'No'
    })
)

# %% [markdown]
# About 76.2% of all injury outcomes are missing.

# %%
crosstab_before = pd.crosstab(force['force_type'], force['subject_injury_clean'], dropna=False)
crosstab_before
# Out:
# subject_injury_clean           No   Yes   NaN
# force_type
# Baton                           0     2     2
# Bodily Force                 1093  1286  7051
# Chemical Irritant             131    41  1421
# Firearm                         2     0     0
# Gun Point Display              33    44    27
# Improvised Weapon              34    40    74
# Less Lethal                     0     0    87
# Less Lethal Projectile          1     2     0
# Maximal Restraint Technique     0     0   170
# Police K9 Bite                  2    44    31
# Taser                         150   172   985

# %% [markdown]
# A key pattern is that some force types, such as 'Maximal Restraint Technique', have almost entirely missing injury information.

# %%
force['subject_injury_clean'] = force['subject_injury_clean'].fillna('Missing')

# %%
crosstab_after = pd.crosstab(force['force_type'], force['subject_injury_clean'])
crosstab_after
# Out:
# subject_injury_clean         Missing    No   Yes
# force_type
# Baton                              2     0     2
# Bodily Force                    7051  1093  1286
# Chemical Irritant               1421   131    41
# Firearm                            0     2     0
# Gun Point Display                 27    33    44
# Improvised Weapon                 74    34    40
# Less Lethal                       87     0     0
# Less Lethal Projectile             0     1     2
# Maximal Restraint Technique      170     0     0
# Police K9 Bite                    31     2    44
# Taser                            985   150   172

# %% [markdown]
# 3.

# %%
metabric = pd.read_csv('/content/data/metabric.csv')
metabric.head()
# Out:
#    Age at Diagnosis Type of Breast Surgery    Cancer Type Chemotherapy  \
# 0             43.19      BREAST CONSERVING  Breast Cancer           NO
# 1             48.87             MASTECTOMY  Breast Cancer          YES
# 2             47.68             MASTECTOMY  Breast Cancer          YES
# 3             76.97             MASTECTOMY  Breast Cancer          YES
# 4             78.77             MASTECTOMY  Breast Cancer           NO
#
#   Hormone Therapy  Lymph nodes examined positive  Mutation Count  \
# 0             YES                            0.0             2.0
# 1             YES                            1.0             2.0
# 2             YES                            3.0             1.0
# 3             YES                            8.0             2.0
# 4             YES                            0.0             4.0
#
#    Nottingham prognostic index  Overall Survival (Months)  \
# 0                        4.020                  84.633333
# 1                        4.030                 163.700000
# 2                        4.050                 164.933333
# 3                        6.080                  41.366667
# 4                        4.062                   7.800000
#
#   Overall Survival Status Radio Therapy  TMB (nonsynonymous)  Tumor Size  \
# 0                0:LIVING           YES             2.615035        10.0
# 1              1:DECEASED            NO             2.615035        15.0
# 2                0:LIVING           YES             1.307518        25.0
# 3              1:DECEASED           YES             2.615035        40.0
# 4              1:DECEASED           YES             5.230071        31.0
#
#    Tumor Stage
# 0          1.0
# 1          2.0
# 2          2.0
# 3          2.0
# 4          4.0

# %%
metabric['Overall Survival Status'].value_counts(dropna=False)
# Out:
# Overall Survival Status
# 1:DECEASED    768
# 0:LIVING      575
# Name: count, dtype: int64

# %%
metabric['overall_survival_dummy'] = (
    metabric['Overall Survival Status']
    .str.strip()
    .str.lower()
    .map({
        'deceased': 0,
        'living': 1
    })
)

# %%
metabric[['Overall Survival Status', 'overall_survival_dummy']].head()
# Out:
#   Overall Survival Status  overall_survival_dummy
# 0                0:LIVING                     NaN
# 1              1:DECEASED                     NaN
# 2                0:LIVING                     NaN
# 3              1:DECEASED                     NaN
# 4              1:DECEASED                     NaN

# %% [markdown]
# 4.

# %%
missing_count = airbnb['Review Scores Rating'].isna().sum()
missing_count
# Out:
# np.int64(8323)

# %% [markdown]
# There are 8323 missing values.

# %%
median_rating = airbnb['Review Scores Rating'].median()
median_rating
# Out:
# 94.0

# %%
airbnb['review_score_imputed'] = airbnb['Review Scores Rating'].fillna(median_rating)

# %% [markdown]
# Median imputation can negatively affect analysis, because the missing reviews are not random. Listings with no reviews might indicate new, inactive, or lower quality ratings. Therefore, assigning thme a higher median score, such as 94, overstates their quality.

# %% [markdown]
# **Q2.** Go to https://sharkattackfile.net/ and download their dataset on shark attacks.

# %% [markdown]
# 1.

# %%
shark_attacks = pd.read_excel('/GSAF5.xls')
shark_attacks.head()
# Out:
#            Date    Year        Type    Country State  \
# 0  20th January  2026.0  Unprovoked  Australia   NSW
# 1  19th January  2026.0  Unprovoked  Australia   NSW
# 2  19th January  2026.0  Unprovoked  Australia   NSW
# 3  18th January  2026.0  Unprovoked  Australia   NSW
# 4  10th January  2026.0  Unprovoked  Australia   NSW
#
#                                 Location           Activity             Name  \
# 0  Point Plomber North of Port Macquarie            Surfing   Paul Zvirdinas
# 1                                Dee Why            Surfing          Unknown
# 2                          North Steyne             Surfing  Andre de Ruyter
# 3   Nielsen Park Vaucluse Sydney Harbour  Jumping off rocks       Nico Antic
# 4                           Avalon Beach            Surfing     Paul Stanton
#
#   Sex Age  ...                         Species                   Source  pdf  \
# 0   M  39  ...                       Bull shark          Bob Myatt GSAF  NaN
# 1   M  11  ...                       Bull shark             Andy Currie  NaN
# 2   M  27  ...  5m shark species not determined  9 News: Bob Myatt GSAF  NaN
# 3   M  12  ...                       Bull shark          Bob Myatt GSAF  NaN
# 4   M   ?  ...                          Unknown          Bob Myatt GSAF  NaN
#
#   href formula href Case Number Case Number.1 original order Unnamed: 21  \
# 0          NaN  NaN         NaN           NaN            NaN         NaN
# 1          NaN  NaN         NaN           NaN            NaN         NaN
# 2          NaN  NaN         NaN           NaN            NaN         NaN
# 3          NaN  NaN         NaN           NaN            NaN         NaN
# 4          NaN  NaN         NaN           NaN            NaN         NaN
#
#   Unnamed: 22
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 23 columns]

# %% [markdown]
# Using 'read_excel' works because the format is an excel file instead of a csv file, which is why 'read_csv' does not work.

# %% [markdown]
# 2.

# %%
shark_attacks = shark_attacks.dropna(axis=1, how='all')

# %% [markdown]
# 3.

# %% [markdown]
# Each observation or row represents a single shark incident. Understanding this matters for cleaning so I do not accidentally aggregate two incidents into one. Additionally, it helps me understand that I should not treat columns as separate observations. Cleaning should include preserving one row per shark incident.

# %% [markdown]
# 4.

# %%
shark_attacks['Year_clean'] = pd.to_numeric(shark_attacks['Year'], errors='coerce')

# %%
shark_attacks['Year_clean'].describe()
# Out:
# count    7068.000000
# mean     1935.953311
# std       270.740135
# min         0.000000
# 25%      1948.000000
# 50%      1986.000000
# 75%      2010.000000
# max      2026.000000
# Name: Year_clean, dtype: float64

# %% [markdown]
# The dataset includes shark attack incidents from as early as the 1940s to more recent years such as 2026.

# %%
shark_attacks_modern = shark_attacks[shark_attacks['Year_clean'] >= 1940]
shark_attacks_modern
# Out:
#               Date    Year        Type           Country  \
# 0     20th January  2026.0  Unprovoked         Australia
# 1     19th January  2026.0  Unprovoked         Australia
# 2     19th January  2026.0  Unprovoked         Australia
# 3     18th January  2026.0  Unprovoked         Australia
# 4     10th January  2026.0  Unprovoked         Australia
# ...            ...     ...         ...               ...
# 5531          1940  1940.0  Unprovoked        NEW GUINEA
# 5532          1940  1940.0  Unprovoked  PAPUA NEW GUINEA
# 5533          1940  1940.0     Invalid      SOUTH AFRICA
# 5534          1940  1940.0     Invalid      SOUTH AFRICA
# 5535          1940  1940.0     Invalid      SOUTH AFRICA
#
#                       State                               Location  \
# 0                       NSW  Point Plomber North of Port Macquarie
# 1                       NSW                                Dee Why
# 2                       NSW                          North Steyne
# 3                       NSW   Nielsen Park Vaucluse Sydney Harbour
# 4                       NSW                           Avalon Beach
# ...                     ...                                    ...
# 5531               Bwagaoia    Bagalina, North coast Misima Island
# 5532    Western Papuan Gulf                                Kerema
# 5533  Eastern Cape Province                           Kidd's Beach
# 5534          KwaZulu-Natal                           Winkelspruit
# 5535  Eastern Cape Province         Kowie River Mouth, Port Alfred
#
#                                       Activity             Name  Sex  Age  \
# 0                                      Surfing   Paul Zvirdinas    M   39
# 1                                      Surfing          Unknown    M   11
# 2                                      Surfing  Andre de Ruyter    M   27
# 3                            Jumping off rocks       Nico Antic    M   12
# 4                                      Surfing     Paul Stanton    M    ?
# ...                                        ...              ...  ...  ...
# 5531                                       NaN       small girl    F  NaN
# 5532                                      male         a native  NaN  NaN
# 5533                                  Swimming              NaN  NaN  NaN
# 5534                                       NaN    Indian female    F  NaN
# 5535  Standing in water with child in her arms           female    F  NaN
#
#       ...                                             Source  \
# 0     ...                                     Bob Myatt GSAF
# 1     ...                                        Andy Currie
# 2     ...                             9 News: Bob Myatt GSAF
# 3     ...                                     Bob Myatt GSAF
# 4     ...                                     Bob Myatt GSAF
# ...   ...                                                ...
# 5531  ...                  A. Bleakley;  A. M. Rapson, p.148
# 5532  ...                           Papuan Villager, 11/1940
# 5533  ...                                  D. Davies, p. 102
# 5534  ...  V.M. Coppleson (1958), p.247; SAF Case #161. U...
# 5535  ...  E. Skaife, V. M. Coppleson (1958), p.247;  M. ...
#
#                                 pdf  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 5531    1940.00.00.e-small-girl.pdf
# 5532        1940.00.00.d-Kerema.pdf
# 5533    1940.00.00.c-KiddsBeach.pdf
# 5534  1940.00.00.b-IndianFemale.pdf
# 5535   1940.00.00.a-Woman-Kowie.pdf
#
#                                            href formula  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 5531  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5532  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5533  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5534  http://sharkattackfile.net/spreadsheets/pdf_di...
# 5535  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href   Case Number  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2                                                   NaN           NaN
# 3                                                   NaN           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 5531  http://sharkattackfile.net/spreadsheets/pdf_di...  1940.00.00.e
# 5532  http://sharkattackfile.net/spreadsheets/pdf_di...  1940.00.00.d
# 5533  http://sharkattackfile.net/spreadsheets/pdf_di...  1940.00.00.c
# 5534  http://sharkattackfile.net/spreadsheets/pdf_di...  1940.00.00.b
# 5535  http://sharkattackfile.net/spreadsheets/pdf_di...  1940.00.00.a
#
#      Case Number.1 original order Unnamed: 21 Unnamed: 22 Year_clean
# 0              NaN            NaN         NaN         NaN     2026.0
# 1              NaN            NaN         NaN         NaN     2026.0
# 2              NaN            NaN         NaN         NaN     2026.0
# 3              NaN            NaN         NaN         NaN     2026.0
# 4              NaN            NaN         NaN         NaN     2026.0
# ...            ...            ...         ...         ...        ...
# 5531  1940.00.00.e         1535.0         NaN         NaN     1940.0
# 5532  1940.00.00.d         1534.0         NaN         NaN     1940.0
# 5533  1940.00.00.c         1533.0         NaN         NaN     1940.0
# 5534  1940.00.00.b         1532.0         NaN         NaN     1940.0
# 5535  1940.00.00.a         1531.0         NaN         NaN     1940.0
#
# [5534 rows x 24 columns]

# %%
attacks_by_year = shark_attacks_modern['Year_clean'].value_counts().sort_index()
attacks_by_year.plot(kind='line')
# Out:
# <Axes: xlabel='Year_clean'>

# %% [markdown]
# Since 2020, shark attacks seem to be declining steeply. However, before that, since around 1980, shark attacks seemed to be increasing overtime until around 2020.

# %% [markdown]
# 5.

# %%
shark_attacks['Age_clean'] = pd.to_numeric(shark_attacks['Age'], errors='coerce')

# %%
import matplotlib.pyplot as plt

# %%
shark_attacks['Age_clean'].hist(bins=30)
plt.xlabel("Age")
plt.ylabel("Count")
plt.title("Histogram of Victim Ages")
plt.show()

# %% [markdown]
# 6.

# %%
shark_attacks['Type_clean'] = (
    shark_attacks['Type']
    .str.strip()
    .str.lower()
    .map({
        'provoked': 'Provoked',
        'unprovoked': 'Unprovoked'
    })
    .fillna('Unknown')
)

# %%
shark_attacks['Type_clean'].value_counts(normalize=True)
# Out:
# Type_clean
# Unprovoked    0.738614
# Unknown       0.170297
# Provoked      0.091089
# Name: proportion, dtype: float64

# %% [markdown]
# About 74% of attacks are unprovoked.

# %% [markdown]
# 7.

# %%
shark_attacks['Fatal_clean'] = (
    shark_attacks['Fatal Y/N']
    .str.strip()
    .str.upper()
    .map({'Y': 'Y', 'N': 'N'})
    .fillna('Unknown')
)

# %% [markdown]
# 8.

# %%
cross = pd.crosstab(shark_attacks['Type_clean'], shark_attacks['Fatal_clean'], normalize='index')
cross
# Out:
# Fatal_clean         N   Unknown         Y
# Type_clean
# Provoked     0.953416  0.013975  0.032609
# Unknown      0.372924  0.460963  0.166113
# Unprovoked   0.742244  0.015128  0.242627

# %% [markdown]
# The attack is more likely to be fatal when unprovoked. This was actually surprising to me as I thought provoked attacks would be more likely to be fatal, because the shark is more likely to be angry.

# %% [markdown]
# **Q3.** Open the "tidy_data.pdf" document available in `https://github.com/ds4e/wrangling`, which is a paper called *Tidy Data* by Hadley Wickham.

# %% [markdown]
# 1. This paper is focused on data tidying and develops a framework that makes cleaning data easier and more effective.

# %% [markdown]
# 2. The tiny data standard intends to make data cleaning and analysis easier. Using this structure simplifies data manipulation by ensuring consistency within the data values and enhancing readability for comprehending the dataset.

# %% [markdown]
# 3.
# - **"Like families, tidy datasets are all alike but every messy dataset is messy in its own way."**
# This means that tidy datasets always follow the same consistent strict rules. For example, each variable is a column and each observation is a row. Messy datasets are unstructured in unique ways and can often be disorganized. For example, scattered variables and inconsistent formatting.
# - **"For a given dataset, it’s usually easy to figure out what are observations and what are variables, but it is surprisingly difficult to precisely define variables and observations in general."** This means that it is easy to understand instantly when looking at a dataset what the rows and column are. However, because data structure is so relative, it is difficult to universally define terms that apply to all data types.

# %% [markdown]
# 4. Values are numbers (if quantitative) or strings (if qualitative) and they belong to a variable and an observation. Variables contain all values that measure the same attribute, such as height, across units. Observations contain all values measured on the same unit, such as a person, across atrributes.

# %% [markdown]
# 5. Tidy data is defined as a way of mapping the meaning of a dataset to its structure. For example, tidy data is when each variable forms a column, each observation forms a row, and each type of observation unit forms a table. Tiday data helps with data analysis as it makes extracting needed variables easier through a standard way of structing a dataset.

# %% [markdown]
# 6. The 5 most common problems with messy datasets are
#
#
# *   Column headers are values, not variable names
# *   Multiple variables are stored in one column
# * Variables are stored in both rows and columns
# * Multiple types of observational units are stored in the same table
# * A single observational unit is stored in multiple tables
#
# The data in table 4 is messy, because the column headers are numeric values (income) instead of variables names.
#
# "Melting" is transforming a dataset from a wide format into a long format. For example, in table 4, melting includes transforming the values in the column header into rows.

# %% [markdown]
# 7. Table 11 is messy, because it has variables stored in both rows and columns. Specifically, it has individual columns (id, year, month), spread across columns (day, d-d31), and across rows (tmin, tmax). Table 12 is tidy and "molten", because it separates the values stored in both rows and columns. Specifically, there is one variable in each column while each row represents a day's observation.

# %% [markdown]
# **Q4.** This question looks at financial transfers from international actors to American universities. In particular, from which countries and giftors are the gifts coming from, and to which institutions are they going?
#
# For this question, `.groupby([vars]).count()` and `.groupby([vars]).sum()` will be especially useful to tally the number of occurrences and sum the values of those occurrences.

# %% [markdown]
# 1.

# %%
import pandas as ps
import matplotlib.pyplot as plt

# %%
foreign_gifts = pd.read_csv('/content/data/ForeignGifts_edu.csv')
foreign_gifts.head()
# Out:
#    ID   OPEID               Institution Name          City State  \
# 0   1  102000  Jacksonville State University  Jacksonville    AL
# 1   2  104700                Troy University          Troy    AL
# 2   3  105100          University of Alabama    Tuscaloosa    AL
# 3   4  105100          University of Alabama    Tuscaloosa    AL
# 4   5  105100          University of Alabama    Tuscaloosa    AL
#
#    Foreign Gift Received Date  Foreign Gift Amount      Gift Type  \
# 0                       43738               250000  Monetary Gift
# 1                       43592               463657       Contract
# 2                       43466              3649107       Contract
# 3                       43472                 1000       Contract
# 4                       43479                49476       Contract
#
#   Country of Giftor                          Giftor Name
# 0             CHINA                                  NaN
# 1             CHINA     Confucius Institute Headquarters
# 2           ENGLAND  Springer Nature Customer Service Ce
# 3      SAUDI ARABIA       Saudi Arabia Education Mission
# 4      SAUDI ARABIA       Saudi Arabia Education Mission

# %% [markdown]
# 2.

# %%
plt.figure()
plt.hist(foreign_gifts['Foreign Gift Amount'].dropna(), bins=50)
plt.xlabel("Foreign Gift Amount ($)")
plt.ylabel("Count")
plt.title("Distribution of Foreign Gift Amounts")
plt.show()

# %%
foreign_gifts['Foreign Gift Amount'].describe()
# Out:
# count    2.822100e+04
# mean     5.882327e+05
# std      3.222011e+06
# min     -5.377700e+05
# 25%      5.700000e+03
# 50%      9.461500e+04
# 75%      3.761420e+05
# max      1.000000e+08
# Name: Foreign Gift Amount, dtype: float64

# %% [markdown]
# It appears that most gifts are small, because the distribution is extremely skewed to the left. Additionally, a small number of very large gifts dominate the total amount, making the mean misleading.

# %% [markdown]
# 3.

# %%
foreign_gifts['Gift Type'].value_counts(normalize=True)
# Out:
# Gift Type
# Contract         0.612097
# Monetary Gift    0.387513
# Real Estate      0.000390
# Name: proportion, dtype: float64

# %% [markdown]
# About 61.2% of the gifts are contracts, about 39% of the gifts are monetary gifts, and about .0004% of the gifts are real estate.

# %% [markdown]
# 4.

# %%
foreign_gifts.groupby('Country of Giftor')['ID'] \
  .count() \
  .sort_values(ascending=False) \
  .head(15)
# Out:
# Country of Giftor
# ENGLAND            3655
# CHINA              2461
# CANADA             2344
# JAPAN              1896
# SWITZERLAND        1676
# SAUDI ARABIA       1610
# FRANCE             1437
# GERMANY            1394
# HONG KONG          1080
# SOUTH KOREA         811
# QATAR               693
# THE NETHERLANDS     512
# KOREA               452
# INDIA               434
# TAIWAN              381
# Name: ID, dtype: int64

# %%
foreign_gifts.groupby('Country of Giftor')['Foreign Gift Amount'] \
  .sum() \
  .sort_values(ascending=False) \
  .head(15)
# Out:
# Country of Giftor
# QATAR                   2706240869
# ENGLAND                 1464906771
# CHINA                   1237952112
# SAUDI ARABIA            1065205930
# BERMUDA                  899593972
# CANADA                   898160656
# HONG KONG                887402529
# JAPAN                    655954776
# SWITZERLAND              619899445
# INDIA                    539556490
# GERMANY                  442475605
# UNITED ARAB EMIRATES     431396357
# FRANCE                   405839396
# SINGAPORE                401157692
# AUSTRALIA                248409202
# Name: Foreign Gift Amount, dtype: int64

# %% [markdown]
# 5.

# %%
top_institutions = (
    foreign_gifts.groupby('Institution Name')['Foreign Gift Amount']
      .sum()
      .sort_values(ascending=False)
      .head(15)
)
top_institutions
# Out:
# Institution Name
# Carnegie Mellon University                       1477922504
# Cornell University                               1289937761
# Harvard University                                954803610
# Massachusetts Institute of Technology             859071692
# Yale University                                   613441311
# Texas A&M University                              521455050
# Johns Hopkins University                          502409595
# Northwestern University                           402316221
# Georgetown University                             379950511
# University of Chicago (The)                       364544338
# University of Colorado Boulder                    360173159
# Duke University                                   343699498
# Brigham Young University                          323509863
# Stanford University                               319561362
# University of Texas MD Anderson Cancer Center     301527419
# Name: Foreign Gift Amount, dtype: int64

# %%
institutions_total = (
    foreign_gifts.groupby('Institution Name')['Foreign Gift Amount']
      .sum()
)
institutions_total
# Out:
# Institution Name
# Adelphi University                                        1000000
# Albert Einstein College of Medicine                       4252385
# Alfred University                                         2711699
# American University (The)                                 3489000
# Amherst College                                            778723
#                                                           ...
# Wright State University                                   1693644
# Xavier University of Louisiana                             706193
# Yale University                                         613441311
# Yeshiva University                                         297397
# Young Americans College of the Performing Arts (The)      1121583
# Name: Foreign Gift Amount, Length: 318, dtype: int64

# %%
plt.figure()
plt.hist(institutions_total, bins=50)
plt.xlabel("Total Foreign Gift Amount Received ($)")
plt.ylabel("Number of Institutions")
plt.title("Distribution of Total Foreign Gifts by Institution")
plt.show()

# %% [markdown]
# 6.

# %%
foreign_gifts.groupby('Giftor Name')['Foreign Gift Amount'] \
  .sum() \
  .sort_values(ascending=False) \
  .head(15)
# Out:
# Giftor Name
# Qatar Foundation                       1166503744
# Qatar Foundation/Qatar National Res     796197000
# Qatar Foundation for Education          373945215
# Anonymous                               338793629
# Saudi Arabian Cultural Mission          275221475
# HCL                                     190000000
# Church of Jesus Christ of LDS           185203715
# Emirates Institute for Advanced Sc      170641244
# QIC                                     148355497
# Anonymous #9                             96334996
# Qatar National Research Fund             79021705
# Government of Saudi Arabia               75192434
# Contracting Party                        69996984
# CMKL University                          67700000
# Royal Embassy of Saudi Arabia            67062486
# Name: Foreign Gift Amount, dtype: int64

# %% [markdown]
# **Q5.** This question provides some practice doing exploratory data analysis and visualization.
#
# We'll use the `college_completion.csv` dataset from the US Department of Education. The "relevant" variables for this question are:
#   - `level` - Level of institution (4-year, 2-year)
#   - `aid_value` - The average amount of student aid going to undergraduate recipients
#   - `control` - Public, Private not-for-profit, Private for-profit
#   - `grad_100_value` - percentage of first-time, full-time, degree-seeking undergraduates who complete a degree or certificate program within 100 percent of expected time (bachelor's-seeking group at 4-year institutions)

# %% [markdown]
# 1.

# %%
college = pd.read_csv('/content/data/college_completion.csv')

# %% [markdown]
# 2.

# %%
college.shape
# Out:
# (3798, 63)

# %%
college.head()
# Out:
#    index  unitid                            chronname        city    state  \
# 0      0  100654               Alabama A&M University      Normal  Alabama
# 1      1  100663  University of Alabama at Birmingham  Birmingham  Alabama
# 2      2  100690                   Amridge University  Montgomery  Alabama
# 3      3  100706  University of Alabama at Huntsville  Huntsville  Alabama
# 4      4  100724             Alabama State University  Montgomery  Alabama
#
#     level                 control  \
# 0  4-year                  Public
# 1  4-year                  Public
# 2  4-year  Private not-for-profit
# 3  4-year                  Public
# 4  4-year                  Public
#
#                                                basic hbcu flagship  ...  \
# 0  Masters Colleges and Universities--larger prog...    X      NaN  ...
# 1  Research Universities--very high research acti...  NaN      NaN  ...
# 2            Baccalaureate Colleges--Arts & Sciences  NaN      NaN  ...
# 3  Research Universities--very high research acti...  NaN      NaN  ...
# 4  Masters Colleges and Universities--larger prog...    X      NaN  ...
#
#    vsa_grad_after6_transfer  vsa_grad_elsewhere_after6_transfer  \
# 0                      36.4                                 5.6
# 1                       NaN                                 NaN
# 2                       NaN                                 NaN
# 3                       0.0                                 0.0
# 4                       NaN                                 NaN
#
#   vsa_enroll_after6_transfer  vsa_enroll_elsewhere_after6_transfer  \
# 0                       17.2                                  11.1
# 1                        NaN                                   NaN
# 2                        NaN                                   NaN
# 3                        0.0                                   0.0
# 4                        NaN                                   NaN
#
#                                              similar  state_sector_ct  \
# 0  232937|100724|405997|113607|139533|144005|2285...               13
# 1  196060|180461|201885|145600|209542|236939|1268...               13
# 2  217925|441511|205124|247825|197647|221856|1353...               16
# 3  232186|133881|196103|196413|207388|171128|1900...               13
# 4  100654|232937|242617|243197|144005|241739|2354...               13
#
#    carnegie_ct  counted_pct  nicknames  cohort_size
# 0          386      99.7|07        NaN        882.0
# 1          106      56.0|07        UAB       1376.0
# 2          252     100.0|07        NaN          3.0
# 3          106      43.1|07        UAH        759.0
# 4          386      88.0|07        ASU       1351.0
#
# [5 rows x 63 columns]

# %% [markdown]
# 3.

# %%
cross_college = pd.crosstab(college['control'], college['level'])
cross_college
# Out:
# level                   2-year  4-year
# control
# Private for-profit         465     527
# Private not-for-profit      68    1180
# Public                     926     632

# %% [markdown]
# It seems that public universities have a large number of 2-year and 4-year, most likely indicating 2-year community colleges. Additionally, private not-for-profit are more heavily 4-year and seldom 2-year.

# %% [markdown]
# 4.

# %%
plt.figure()
college['grad_100_value'].plot(kind='kde')
plt.xlabel('Graduation Rate')
plt.ylabel('Density')
plt.title('Kernel Density of Graduation Rates')
plt.show()

# %%
college_desc = college['grad_100_value'].describe()
college_desc
# Out:
# count    3467.000000
# mean       28.364465
# std        23.312730
# min         0.000000
# 25%         9.000000
# 50%        22.500000
# 75%        43.650000
# max       100.000000
# Name: grad_100_value, dtype: float64

# %%
condition = college[['grad_100_value', 'control']]
condition
# Out:
#       grad_100_value                 control
# 0               10.0                  Public
# 1               29.4                  Public
# 2                0.0  Private not-for-profit
# 3               16.5                  Public
# 4                8.8                  Public
# ...              ...                     ...
# 3793             0.0  Private not-for-profit
# 3794            51.5  Private not-for-profit
# 3795            37.5      Private for-profit
# 3796            42.1      Private for-profit
# 3797            34.8      Private for-profit
#
# [3798 rows x 2 columns]

# %%
for c in condition['control'].dropna().unique():
    subset = condition[condition['control'] == c]['grad_100_value']
    if subset.notna().sum() > 5:
        plt.figure()
        subset.dropna().plot(kind='kde')
        plt.xlabel('Graduation Rate')
        plt.ylabel('Density')
        plt.title(f'Kernel Density of Graduation Rates ({c})')
        plt.show()

# %%
college.groupby('control')['grad_100_value'].describe()
# Out:
#                          count       mean        std  min    25%   50%    75%  \
# control
# Private for-profit       779.0  29.108858  25.601687  0.0   6.95  24.7  46.75
# Private not-for-profit  1189.0  41.660976  23.551231  0.0  25.00  41.0  58.30
# Public                  1499.0  17.430887  14.729443  0.0   6.90  13.2  23.25
#
#                           max
# control
# Private for-profit      100.0
# Private not-for-profit  100.0
# Public                   97.8

# %% [markdown]
# Private not-for-profit institutions appear to have the most favorable graduation rates.

# %% [markdown]
# 5.

# %%
plt.figure()
plt.scatter(college['aid_value'], college['grad_100_value'])
plt.xlabel('Average Aid Value')
plt.ylabel('Graduation Rate')
plt.title('Graduation Rate By Aid Value')
plt.show()

# %%
cov = college['grad_100_value'].cov(college['aid_value'])
cov
# Out:
# np.float64(88610.48316902434)

# %%
corr = college['grad_100_value'].corr(college['aid_value'])
corr
# Out:
# np.float64(0.5758792845936073)

# %% [markdown]
# The scatterplot shows a weak positive relationship between aid value and graduation rate. Specifically, institutions offering higher aid often have somewhat higher graduation rates.

# %%
condition_control = college[['grad_100_value', 'aid_value', 'control']].dropna()
condition_control
# Out:
#       grad_100_value  aid_value                 control
# 0               10.0     7142.0                  Public
# 1               29.4     6088.0                  Public
# 2                0.0     2540.0  Private not-for-profit
# 3               16.5     6647.0                  Public
# 4                8.8     7256.0                  Public
# ...              ...        ...                     ...
# 3793             0.0     4860.0  Private not-for-profit
# 3794            51.5     9395.0  Private not-for-profit
# 3795            37.5     3291.0      Private for-profit
# 3796            42.1     3434.0      Private for-profit
# 3797            34.8     5379.0      Private for-profit
#
# [3466 rows x 3 columns]

# %%
for c in condition_control['control'].unique():
    subset = condition_control[condition_control['control'] == c]

    plt.figure()
    plt.scatter(subset['aid_value'], subset['grad_100_value'])
    plt.xlabel('Aid Value')
    plt.ylabel('Graduation Rate')
    plt.title(f'Aid By Graduation Rate ({c})')
    plt.show()

# %%
cov_control = condition_control.groupby('control')[['grad_100_value', 'aid_value']].cov()
cov_control
# Out:
#                                        grad_100_value     aid_value
# control
# Private for-profit     grad_100_value      654.449527  6.897525e+03
#                        aid_value          6897.524957  2.048899e+06
# Private not-for-profit grad_100_value      554.660462  1.092741e+05
#                        aid_value        109274.123337  5.948465e+07
# Public                 grad_100_value      216.956489  1.535515e+04
#                        aid_value         15355.146212  4.668472e+06

# %%
corr_control = condition_control.groupby('control')[['grad_100_value', 'aid_value']].corr()
corr_control
# Out:
#                                        grad_100_value  aid_value
# control
# Private for-profit     grad_100_value        1.000000   0.188363
#                        aid_value             0.188363   1.000000
# Private not-for-profit grad_100_value        1.000000   0.601591
#                        aid_value             0.601591   1.000000
# Public                 grad_100_value        1.000000   0.482481
#                        aid_value             0.482481   1.000000

# %% [markdown]
# It appears that public institutions have a weak or near zero positive relationship between aid value and graduation rate, while private not-for-profit institutions have a strong positive relationship and private for-profit institutions have little to no positive relationship. Specifically, within private not-for-profit institutions, higher aid tends to be associated with higher graduation rates.

# %% [markdown]
# **Q6.** In class, we talked about how to compute the sample mean of a variable $X$,
# $$
# m(X) = \dfrac{1}{N} \sum_{i=1}^N x_i
# $$
# and sample covariance of two variables $X$ and $Y$,
# $$
# \text{cov}(X,Y) = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))(y_i - m(Y))).
# $$
# Recall, the sample variance of $X$ is
# $$
# s^2 = \dfrac{1}{N} \sum_{i=1}^N (x_i - m(X))^2.
# $$
# It can be very helpful to understand some basic properties of these statistics. If you want to write your calculations on a piece of paper, take a photo, and upload that to your GitHub repo, that's probably easiest.
#
# We're going to look at **linear transformations** of $X$, $Y = a + bX$. So we take each value of $X$, $x_i$, and transform it as $y_i = a + b x_i$.
#
# 1. Show that $m(a + bX) = a+b \times m(X)$.
# 2. Show that $ \text{cov}(X,X) = s^2$.
# 3. Show that $\text{cov}(X,a+bY) = b \times \text{cov}(X,Y)$
# 4. Show that $\text{cov}(a+bX,a+bY) = b^2 \text{cov}(X,Y) $. Notice, this also means that $\text{cov}(bX, bX) = b^2 s^2$.
# 5. Suppose $b>0$ and let the median of $X$ be $\text{med}(X)$. Is it true that the median of $a+bX$ is equal to $a + b \times \text{med}(X)$? Is the IQR of $a + bX$ equal to $a + b \times \text{IQR}(X)$?
# 6. Show by example that the means of $X^2$ and $\sqrt{X}$ are generally not $(m(X))^2$ and $\sqrt{m(X)}$. So, the results we derived above really depend on the linearity of the transformation $Y = a + bX$, and transformations like $Y = X^2$ or $Y = \sqrt{X}$ will not behave in a similar way.

# %% [markdown]
# **Q7.** This question provides some practice doing exploratory data analysis and visualization.
#
# We'll use the `ames_prices.csv` dataset. The "relevant" variables for this question are:
#   - `price` - Sale price value of the house
#   - `Bldg.Type` - Building type of the house (single family home, end-of-unit townhome, duplex, interior townhome, two-family conversion)
#
# 1. Load the `college_completion.csv` data with Pandas.
# 2. Make a kernel density plot of price and compute a describe table. Now, make a kernel density plot of price conditional on building type, and use `.groupby()` to make a describe type for each type of building. Which building types are the most expensive, on average? Which have the highest variance in transaction prices?
# 3. Make an ECDF plot of price, and compute the sample minimum, .25 quantile, median, .75 quantile, and sample maximum (i.e. a 5-number summary).
# 4. Make a boxplot of price. Are there outliers? Make a boxplot of price conditional on building type. What patterns do you see?
# 5. Make a dummy variable indicating that an observation is an outlier.
# 6. Winsorize the price variable, and compute a new kernel density plot and describe table. How do the results change?
