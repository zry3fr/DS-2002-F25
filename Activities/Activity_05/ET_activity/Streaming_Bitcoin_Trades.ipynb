# %% [markdown]
# # Streaming Data Acquisition - From Raw Stream to Clean CSV

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 1: Setup and Architecture

# %% [markdown]
# ### Install the necessary libraries:
# 1. **websocket-client**: To establish the persistent connection.
# 2. **pandas**: To process, clean, and export the collected data.

# %%
# !pip install websocket-client pandas
print("Dependencies installed successfully.")
# Out:
# Requirement already satisfied: websocket-client in /home/codespace/.local/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Dependencies installed successfully.

# %%
## Import all required Python modules

# %%
import websocket
import json
import time
import threading
import pandas as pd
from datetime import datetime

print("Modules imported.")
# Out:
# Modules imported.

# %% [markdown]
# ### Define Global Configuration and Storage
# This cell sets the target URL and initializes the empty list that will collect all the raw messages pushed from the server.

# %%
# --- Configuration ---
# Target URL for the Binance BTC/USDT trade stream (using the stable fstream endpoint)
STREAM_URL = "wss://fstream.binance.com/ws/btcusdt@trade" 

# --- Global Storage ---
# This list will collect every single message (event) pushed by the server.
raw_data_collector = []

print(f"Target Stream URL set: {STREAM_URL}")
print("Raw data collector initialized.")
# Out:
# Target Stream URL set: wss://fstream.binance.com/ws/btcusdt@trade
# Raw data collector initialized.

# %% [markdown]
# ### Define the `on_open` Callback
# This function runs only once when the persistent connection is successfully established.

# %%
def on_open(ws):
    """Callback: Executed when the connection handshake is successful."""
    print("--- Connection Established. Starting Real-Time Data Stream ---")
    
print("on_open callback defined.")
# Out:
# on_open callback defined.

# %% [markdown]
# ### Define the `on_error` and `on_close` Callbacks
# These functions handle connection failures and the graceful shutdown of the stream.

# %%
def on_error(ws, error):
    """Callback: Executed if an error occurs during the connection."""
    print(f"--- Connection Error: {error} ---")

def on_close(ws, close_status_code, close_msg):
    """Callback: Executed when the connection is intentionally closed."""
    print("--- Connection Closed ---")
    
print("on_error and on_close callbacks defined.")
# Out:
# on_error and on_close callbacks defined.

# %% [markdown]
# ### Define the `on_message` Callback (Raw Capture Logic)
# This is the most critical function. It runs for every incoming message. For the first run, we will not filter anything.

# %%
def on_message(ws, message):
    """Callback: Executed for EVERY message pushed by the server."""
    global raw_data_collector
    
    try:
        data = json.loads(message)
        
        # 1. Store the RAW, unfiltered message dictionary
        raw_data_collector.append(data)
        
        # 2. Extract and format key fields for immediate screen output
        trade_time = datetime.fromtimestamp(data['E'] / 1000).strftime('%H:%M:%S')
        price = float(data.get('p', 0))
        volume = float(data.get('q', 0))
        
        # Print everything that comes in, including potential 0-value keep-alives
        print(f"[{trade_time}] RAW Trade: Price=${price:,.2f} | Volume={volume}")

    except Exception as e:
        # Ignore errors from malformed JSON (rare, but possible)
        pass 
    
print("on_message callback defined for RAW data capture.")
# Out:
# on_message callback defined for RAW data capture.

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 2: RAW Stream Capture and Observation

# %% [markdown]
# ### Create the WebSocket Client Object

# %%
# Clear the collector list before starting a new run
raw_data_collector = []

# Create the WebSocketApp instance, linking the URL to the callback functions
ws = websocket.WebSocketApp(
    STREAM_URL,
    on_message=on_message,
    on_open=on_open,
    on_error=on_error,
    on_close=on_close
)

print("WebSocket client object created, ready to connect.")
# Out:
# WebSocket client object created, ready to connect.

# %% [markdown]
# ### Start, Run, and Close the Stream Listener
# This cell starts the connection in a separate thread and uses time.sleep() to control the duration.

# %%
print("Starting RAW stream listener for 15 seconds. OBSERVE THE OUTPUT CAREFULLY.")

# Run the socket connection in a separate thread
wst = threading.Thread(target=ws.run_forever)
wst.daemon = True
wst.start()

# Hold the main thread execution for 15 seconds
time.sleep(15) 

print("Time's up. Attempting to close connection...")

# Close the connection gracefully.
ws.close() 

print(f"\nFinished RAW capture. Collected {len(raw_data_collector)} total raw messages.")
# Out:
# Starting RAW stream listener for 15 seconds. OBSERVE THE OUTPUT CAREFULLY.
# --- Connection Established. Starting Real-Time Data Stream ---
# [00:01:56] RAW Trade: Price=$114,222.00 | Volume=0.02
# [00:01:56] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:01:57] RAW Trade: Price=$114,222.00 | Volume=0.039
# [00:01:57] RAW Trade: Price=$114,221.90 | Volume=0.021
# [00:01:57] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:01:57] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:01:57] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:01:57] RAW Trade: Price=$114,222.00 | Volume=0.98
# [00:01:57] RAW Trade: Price=$114,221.90 | Volume=0.007
# [00:01:57] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:01:57] RAW Trade: Price=$114,222.00 | Volume=0.024
# [00:01:57] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:01:58] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:01:58] RAW Trade: Price=$114,222.00 | Volume=0.01
# [00:01:58] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:01:58] RAW Trade: Price=$114,222.00 | Volume=0.083
# [00:01:58] RAW Trade: Price=$114,222.00 | Volume=0.01
# [00:01:58] RAW Trade: Price=$114,222.00 | Volume=0.002
# [00:01:58] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:01:59] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:01:59] RAW Trade: Price=$114,221.90 | Volume=0.01
# [00:01:59] RAW Trade: Price=$114,221.90 | Volume=0.016
# [00:01:59] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:00] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:02:00] RAW Trade: Price=$114,222.00 | Volume=0.01
# [00:02:00] RAW Trade: Price=$114,222.00 | Volume=0.027
# [00:02:00] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:02:00] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:02:00] RAW Trade: Price=$114,222.00 | Volume=0.039
# [00:02:00] RAW Trade: Price=$114,221.90 | Volume=0.047
# [00:02:00] RAW Trade: Price=$114,221.90 | Volume=0.04
# [00:02:00] RAW Trade: Price=$114,221.90 | Volume=0.046
# [00:02:00] RAW Trade: Price=$114,222.00 | Volume=0.008
# [00:02:01] RAW Trade: Price=$114,221.90 | Volume=0.046
# [00:02:01] RAW Trade: Price=$114,222.00 | Volume=0.021
# [00:02:01] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:01] RAW Trade: Price=$114,221.90 | Volume=0.048
# [00:02:02] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:02:02] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:02] RAW Trade: Price=$114,221.90 | Volume=0.318
# [00:02:02] RAW Trade: Price=$114,221.90 | Volume=0.092
# [00:02:02] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:02] RAW Trade: Price=$114,222.00 | Volume=0.068
# [00:02:02] RAW Trade: Price=$0.00 | Volume=0.0
# [00:02:02] RAW Trade: Price=$114,222.00 | Volume=0.001
# [00:02:02] RAW Trade: Price=$114,221.90 | Volume=0.009
# [00:02:02] RAW Trade: Price=$114,221.90 | Volume=0.008
# [00:02:02] RAW Trade: Price=$114,221.90 | Volume=0.039
# [00:02:02] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:02] RAW Trade: Price=$114,221.90 | Volume=0.066
# [00:02:02] RAW Trade: Price=$114,221.90 | Volume=0.004
# [00:02:02] RAW Trade: Price=$114,221.90 | Volume=0.014
# [00:02:02] RAW Trade: Price=$114,221.90 | Volume=0.153
# [00:02:03] RAW Trade: Price=$114,222.00 | Volume=0.012
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.158
# [00:02:03] RAW Trade: Price=$114,222.00 | Volume=0.005
# [00:02:03] RAW Trade: Price=$114,222.00 | Volume=0.008
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.144
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.008
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.015
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.019
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.073
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.027
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.087
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.087
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.399
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.015
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.01
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.1
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.082
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.01
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.145
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.165
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.438
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.008
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.008
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.041
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.009
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.599
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=2.402
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.122
# [00:02:03] RAW Trade: Price=$114,221.90 | Volume=0.006
# [00:02:03] RAW Trade: Price=$114,221.80 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.80 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.80 | Volume=0.004
# [00:02:03] RAW Trade: Price=$114,221.80 | Volume=0.015
# [00:02:03] RAW Trade: Price=$114,221.80 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.80 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.80 | Volume=0.053
# [00:02:03] RAW Trade: Price=$114,221.80 | Volume=0.349
# [00:02:03] RAW Trade: Price=$114,221.80 | Volume=0.417
# [00:02:03] RAW Trade: Price=$114,221.80 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.80 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.80 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.70 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,221.60 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.60 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,221.20 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,220.80 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,220.40 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,220.10 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,220.00 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,219.80 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,219.80 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,219.20 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,219.10 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,218.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,218.60 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,218.40 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,218.00 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,218.00 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,218.00 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,217.50 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,217.40 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,217.30 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.033
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.054
# [00:02:03] RAW Trade: Price=$114,217.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,216.80 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,216.60 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,216.60 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,216.30 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,216.20 | Volume=0.009
# [00:02:03] RAW Trade: Price=$114,216.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,216.00 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,215.50 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,215.40 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,215.20 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,215.20 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,215.20 | Volume=0.017
# [00:02:03] RAW Trade: Price=$114,215.20 | Volume=0.004
# [00:02:03] RAW Trade: Price=$114,215.20 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,215.20 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,214.60 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,214.30 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,214.30 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,214.20 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,214.10 | Volume=0.01
# [00:02:03] RAW Trade: Price=$114,213.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,213.00 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,213.00 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,212.80 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,212.20 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,212.10 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,211.90 | Volume=0.005
# [00:02:03] RAW Trade: Price=$114,211.80 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,211.40 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,211.00 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.80 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.80 | Volume=0.006
# [00:02:03] RAW Trade: Price=$114,210.80 | Volume=0.004
# [00:02:03] RAW Trade: Price=$114,210.80 | Volume=0.008
# [00:02:03] RAW Trade: Price=$114,210.80 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.80 | Volume=0.006
# [00:02:03] RAW Trade: Price=$114,210.80 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.80 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.80 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.80 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.70 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.016
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.008
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.011
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.004
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.035
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.004
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.004
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.004
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.003
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.005
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.60 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.50 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.50 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.40 | Volume=0.444
# [00:02:03] RAW Trade: Price=$114,210.40 | Volume=0.006
# [00:02:03] RAW Trade: Price=$114,210.40 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.40 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.40 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.40 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.30 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.30 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.20 | Volume=0.165
# [00:02:03] RAW Trade: Price=$114,210.20 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.20 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.20 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.20 | Volume=0.008
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.345
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.345
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.15
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.15
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.172
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.059
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.006
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.004
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.008
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.087
# [00:02:03] RAW Trade: Price=$114,210.10 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,210.00 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.00 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.00 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.00 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,210.00 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,209.90 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,209.80 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,209.80 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,209.70 | Volume=0.147
# [00:02:03] RAW Trade: Price=$114,209.70 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,209.70 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,209.70 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,209.70 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,209.70 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,209.50 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,209.50 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,209.60 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,209.50 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,209.00 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,209.00 | Volume=0.087
# [00:02:03] RAW Trade: Price=$114,208.50 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,208.40 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,208.30 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,208.30 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,208.30 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,208.30 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,208.30 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,207.80 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,207.50 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,207.20 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,207.20 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,207.10 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,206.60 | Volume=0.002
# [00:02:03] RAW Trade: Price=$114,206.40 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,206.30 | Volume=0.006
# [00:02:03] RAW Trade: Price=$114,206.30 | Volume=0.024
# [00:02:03] RAW Trade: Price=$114,206.30 | Volume=0.004
# [00:02:03] RAW Trade: Price=$114,206.30 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,206.30 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,206.30 | Volume=0.004
# [00:02:03] RAW Trade: Price=$114,206.30 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,206.20 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,206.20 | Volume=0.001
# [00:02:03] RAW Trade: Price=$114,206.20 | Volume=0.009
# [00:02:03] RAW Trade: Price=$114,206.20 | Volume=0.005
# [00:02:04] RAW Trade: Price=$114,206.20 | Volume=0.023
# [00:02:04] RAW Trade: Price=$114,206.20 | Volume=0.023
# [00:02:04] RAW Trade: Price=$114,206.20 | Volume=0.065
# [00:02:05] RAW Trade: Price=$114,206.20 | Volume=0.044
# [00:02:05] RAW Trade: Price=$114,206.10 | Volume=0.2
# [00:02:05] RAW Trade: Price=$114,206.20 | Volume=0.009
# [00:02:05] RAW Trade: Price=$114,206.10 | Volume=0.001
# [00:02:06] RAW Trade: Price=$114,206.20 | Volume=0.02
# [00:02:06] RAW Trade: Price=$114,206.20 | Volume=0.004
# [00:02:06] RAW Trade: Price=$114,206.20 | Volume=0.08
# [00:02:06] RAW Trade: Price=$0.00 | Volume=0.0
# [00:02:06] RAW Trade: Price=$114,206.10 | Volume=0.01
# [00:02:07] RAW Trade: Price=$114,206.20 | Volume=0.051
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.001
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.001
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.001
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.001
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.002
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.009
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.003
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.001
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.087
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.002
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.001
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.057
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.003
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.001
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.001
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=1.142
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.049
# [00:02:07] RAW Trade: Price=$114,206.10 | Volume=0.032
# [00:02:07] RAW Trade: Price=$0.00 | Volume=0.0
# [00:02:07] RAW Trade: Price=$114,206.20 | Volume=0.012
# [00:02:08] RAW Trade: Price=$114,206.10 | Volume=0.001
# [00:02:08] RAW Trade: Price=$114,206.20 | Volume=0.014
# [00:02:08] RAW Trade: Price=$114,206.20 | Volume=0.008
# [00:02:08] RAW Trade: Price=$114,206.20 | Volume=0.001
# [00:02:08] RAW Trade: Price=$114,206.10 | Volume=0.005
# [00:02:08] RAW Trade: Price=$114,206.20 | Volume=0.022
# [00:02:08] RAW Trade: Price=$114,206.20 | Volume=0.001
# [00:02:08] RAW Trade: Price=$114,206.20 | Volume=0.029
# [00:02:08] RAW Trade: Price=$114,206.20 | Volume=0.017
# [00:02:08] RAW Trade: Price=$114,206.10 | Volume=0.001
# [00:02:08] RAW Trade: Price=$114,206.10 | Volume=0.048
# [00:02:08] RAW Trade: Price=$114,206.10 | Volume=0.043
# [00:02:08] RAW Trade: Price=$114,206.20 | Volume=0.047
# [00:02:08] RAW Trade: Price=$114,206.20 | Volume=0.001
# [00:02:09] RAW Trade: Price=$114,206.20 | Volume=0.033
# [00:02:09] RAW Trade: Price=$114,206.20 | Volume=0.017
# [00:02:09] RAW Trade: Price=$114,206.20 | Volume=0.002
# [00:02:09] RAW Trade: Price=$114,206.10 | Volume=0.039
# [00:02:09] RAW Trade: Price=$114,206.10 | Volume=0.01
# [00:02:09] RAW Trade: Price=$114,206.10 | Volume=0.002
# [00:02:09] RAW Trade: Price=$114,206.10 | Volume=0.054
# [00:02:09] RAW Trade: Price=$114,206.20 | Volume=0.021
# [00:02:09] RAW Trade: Price=$114,206.10 | Volume=0.125
# [00:02:09] RAW Trade: Price=$114,206.20 | Volume=0.001
# [00:02:10] RAW Trade: Price=$114,206.20 | Volume=0.003
# Time's up. Attempting to close connection...
# --- Connection Closed ---
#
# Finished RAW capture. Collected 364 total raw messages.

# %% [markdown]
# ### Commentary - Why the $0 Trades?
#
# --- Observation: The Data Quality Problem ---
#
# You should have observed several messages showing Price=$0.00 or Volume=0.
#
# These are **Keep-Alive (Ping/Pong) Messages**. They are network heartbeats, NOT valid trades.
#
# If we analyzed this raw data, the 0-values would skew our average price and volume calculations.
#
# Our next step is to apply a **Filter** to discard them.

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 3: Data Transformation and Export

# %% [markdown]
# ### Load Raw Data into Pandas
# This is the start of the Transformation (T) phase from ETL.

# %%
# Convert the list of dictionaries collected in Phase 2 into a Pandas DataFrame
df_raw = pd.DataFrame(raw_data_collector)

print(f"DataFrame loaded with {len(df_raw)} raw messages.")
print("Raw DataFrame columns:")
print(df_raw.columns.tolist())
display(df_raw.head())
# Out:
# DataFrame loaded with 364 raw messages.
# Raw DataFrame columns:
# ['e', 'E', 'T', 's', 't', 'p', 'q', 'X', 'm']
#        e              E              T        s           t          p      q  \
# 0  trade  1759190516088  1759190516088  BTCUSDT  6666779974  114222.00  0.020
# 1  trade  1759190516887  1759190516887  BTCUSDT  6666779975  114222.00  0.001
# 2  trade  1759190517087  1759190517087  BTCUSDT  6666779976  114222.00  0.039
# 3  trade  1759190517128  1759190517128  BTCUSDT  6666779977  114221.90  0.021
# 4  trade  1759190517166  1759190517166  BTCUSDT  6666779978  114222.00  0.001
#
#         X      m
# 0  MARKET  False
# 1  MARKET  False
# 2  MARKET  False
# 3  MARKET   True
# 4  MARKET  False

# %% [markdown]
# ### Data Preparation (Type Conversion)
# The price and volume columns were read as strings or objects. We must convert them to numeric types before filtering.

# %%
# Convert price ('p') and volume ('q') columns to numeric types.
df_raw['p'] = pd.to_numeric(df_raw['p'], errors='coerce')
df_raw['q'] = pd.to_numeric(df_raw['q'], errors='coerce')

print("Price ('p') and Volume ('q') columns converted to numeric (float).")
# Out:
# Price ('p') and Volume ('q') columns converted to numeric (float).

# %% [markdown]
# ### Apply the Cleaning Filter
# This cell applies the filter to eliminate the keep-alive messages.

# %%
print(f"Messages before filtering: {len(df_raw)}")

# --- APPLY THE DATA QUALITY FILTER ---
# A valid trade must have a positive price AND a positive volume.
df_clean = df_raw[(df_raw['p'] > 0) & (df_raw['q'] > 0)].copy()

print(f"Messages after filtering: {len(df_clean)}")
print(f"Successfully filtered out {len(df_raw) - len(df_clean)} keep-alive messages.")

display(df_clean.head())
# Out:
# Messages before filtering: 364
# Messages after filtering: 361
# Successfully filtered out 3 keep-alive messages.
#        e              E              T        s           t         p      q  \
# 0  trade  1759190516088  1759190516088  BTCUSDT  6666779974  114222.0  0.020
# 1  trade  1759190516887  1759190516887  BTCUSDT  6666779975  114222.0  0.001
# 2  trade  1759190517087  1759190517087  BTCUSDT  6666779976  114222.0  0.039
# 3  trade  1759190517128  1759190517128  BTCUSDT  6666779977  114221.9  0.021
# 4  trade  1759190517166  1759190517166  BTCUSDT  6666779978  114222.0  0.001
#
#         X      m
# 0  MARKET  False
# 1  MARKET  False
# 2  MARKET  False
# 3  MARKET   True
# 4  MARKET  False

# %% [markdown]
# ### Add Human-Readable Columns
# The raw data uses short keys like 'E' (Event Time) and 's' (Symbol). We create descriptive columns for the final CSV.

# %%
# Convert 'E' (milliseconds since epoch) to a readable timestamp
df_clean['Trade_Time'] = pd.to_datetime(df_clean['E'], unit='ms')

# Create descriptive columns
df_clean['Price_USD'] = df_clean['p']
df_clean['Volume_BTC'] = df_clean['q']

print("Human-readable columns (Trade_Time, Price_USD, Volume_BTC) created.")
# Out:
# Human-readable columns (Trade_Time, Price_USD, Volume_BTC) created.

# %% [markdown]
# ### Select Final Columns
# Select only the essential, clean, and formatted columns for the final file.

# %%
# Select and rename final columns for a clean output structure
df_final = df_clean[['Trade_Time', 'Price_USD', 'Volume_BTC', 's']].rename(
    columns={'s': 'Symbol'}
)

print("Final DataFrame structure prepared.")
display(df_final.head())
# Out:
# Final DataFrame structure prepared.
#                Trade_Time  Price_USD  Volume_BTC   Symbol
# 0 2025-09-30 00:01:56.088   114222.0       0.020  BTCUSDT
# 1 2025-09-30 00:01:56.887   114222.0       0.001  BTCUSDT
# 2 2025-09-30 00:01:57.087   114222.0       0.039  BTCUSDT
# 3 2025-09-30 00:01:57.128   114221.9       0.021  BTCUSDT
# 4 2025-09-30 00:01:57.166   114222.0       0.001  BTCUSDT

# %% [markdown]
# ### Export to CSV
# This is the Load (L) phase of ETL.

# %%
# Define the output filename
output_filename = 'btc_usdt_stream_clean.csv'

# Export the clean DataFrame to a CSV file without the pandas index
df_final.to_csv(output_filename, index=False)

print(f"--- Load Phase Complete ---")
print(f"Clean, filtered stream data successfully exported to: {output_filename}")
# Out:
# --- Load Phase Complete ---
# Clean, filtered stream data successfully exported to: btc_usdt_stream_clean.csv
